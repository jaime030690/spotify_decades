# %%
import pandas as pd
import numpy as np
import matpotlib
import matplotlib.pyplot as plt

# %%
# Load CSV onto dataframe
df = pd.read_csv('output.csv')
df
# Out:
#                                    track                   artist  \
# 0                              Checkmate              Lamb of God
# 1                             Inside Out  Five Finger Death Punch
# 2                 The End of All We Know        Bleed From Within
# 3                             Nero Forte                 Slipknot
# 4                                  Noise                Nightwish
# ..                                   ...                      ...
# 56                                  Fade        Catch Your Breath
# 57                           Counterfeit       Wolves At The Gate
# 58                         The Red Baron                  Sabaton
# 59  MAYDAY (feat. Ryo from Crystal Lake)                 coldrain
# 60                            Protection                   Alcest
#
#                                      uri  mode  key_signature  key_integer  \
# 0   spotify:track:6q72OHGM81Zs5q5jx7YZLR     1              2            2
# ...

# %%
def create_heatmap(x, y, xlabel, ylabel):

    plt.hist2d(x, y, cmap = 'viridis')
    plt.title(f'{xlabel} by {ylabel} Heatmap')
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.show()

# %%
x, y = df['key_integer'], df['bpm']

create_heatmap(x, y, 'Key Integer', 'BPM')

# %%
x, y = df['key_integer'], df['time_signature']

create_heatmap(x, y, 'Key Integer', 'Time Signature')
